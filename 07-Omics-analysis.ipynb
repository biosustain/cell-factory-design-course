# %%
from bokeh.plotting import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="55d8b830-8b63-4af0-9f8c-8e97d7195b99">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Read the counts with pandas.
#
# **pandas** is an efficient library to handle tabular data.
# It provides a DataFrame class similar to *R* data.frame.
#
# The data is the counts normalized by gene length. This is an example of how to use the code. In real life examples it should be RPKM or expression values.

# %%
from pandas import DataFrame

# %%
samples = DataFrame.from_csv('data/GSE71562_normalized.csv')

# %%
samples.head()
# Out:
#          E14R012a01  E14R012a02  E14R012a03  E14R012a04  E14R012a05  \
# bnumber
# b0001      6.923077    9.692308   10.276923    9.676923    7.184615
# b0002      9.127539    7.154346    8.335906   14.721771    5.248172
# b0003      5.783262    5.356223    5.854077   11.162017    3.140558
# b0004      8.189736    6.174184    6.796267   11.091757    3.699844
# b0005      0.317568    0.219595    0.297297    0.418919    0.192568
#
#          E14R012a06  E14R012b01  E14R012b02  E14R012b03  E14R012b04  \
# bnumber
# b0001      5.815385    4.984615    9.153846   11.030769   16.107692
# b0002      2.367181    4.750609    4.254265   11.614541   12.418359
# b0003      2.314378    3.947425    3.517167    6.687768    8.754292
# b0004      2.967341    4.258165    3.727838    8.034215    7.951788
# b0005      0.206081    0.212838    0.185811    0.358108    0.300676
#
#          E14R012b05  E14R012b06  E14R012c01  E14R012c02  E14R012c03  \
# bnumber
# b0001     19.861538   22.446154    5.969231   13.830769   19.415385
# b0002     16.333063   12.347685    2.469943    7.501625   14.976442
# b0003     10.740343    9.646996    2.036481    6.729614   11.674893
# b0004     10.874806   10.173406    2.287714    8.028771   13.246501
# b0005      0.435811    0.469595    0.097973    0.402027    0.625000
#
#          E14R012c04  E14R012c05  E14R012c06
# bnumber
# b0001     16.030769    7.046154   13.261538
# b0002     12.170593    6.330626    7.261576
# b0003      8.254292    3.769313    5.448498
# b0004      9.359253    4.303266    6.218507
# b0005      0.506757    0.179054    0.222973

# %% [markdown]
# ### Load *E. coli* model

# %%
from cameo import models

# %%
ecoli = models.bigg.iJO1366

# %% [markdown]
# ### Keep metabolic genes only

# %%
model_filter = [g.id for g in ecoli.genes if g.id in samples.index]
samples = samples.loc[model_filter]

# %% [markdown]
# ### Aggregate the replicas using median

# %%
timepoints = {
    "t0":  ["E14R012a01", "E14R012b01", "E14R012c01"],
    "t05": ["E14R012a02", "E14R012b02", "E14R012c02"],
    "t1":  ["E14R012a03", "E14R012b03", "E14R012c03"],
    "t2":  ["E14R012a04", "E14R012b04", "E14R012c04"],
    "t5":  ["E14R012a05", "E14R012b05", "E14R012c05"],
    "t10": ["E14R012a06", "E14R012b06", "E14R012c06"],
}

# %%
for t, columns in timepoints.items():
    samples[t] = samples[columns].mean(axis=1)

# %%
samples = samples[[k for k in timepoints]]

# %% [markdown]
# ### Build the expression profile from the data

# %%
from driven.data_sets import ExpressionProfile

# %%
data = ExpressionProfile.from_data_frame(samples)
data
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>t2</th>
#       <th>t1</th>
#       <th>t5</th>
#       <th>t05</th>
#       <th>t10</th>
#       <th>t0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>b2215</th>
#       <td>76.829556</td>
#       <td>73.844968</td>
#       <td>39.760351</td>
#       <td>46.451496</td>
#       <td>28.883348</td>
#       <td>37.355999</td>
#     </tr>
#     <tr>
#       <th>b1377</th>
#       <td>0.013828</td>
#       <td>0.008826</td>
#       <td>0.013239</td>
#       <td>0.011180</td>
#       <td>0.020594</td>
#       <td>0.010591</td>
#     </tr>
#     <tr>
#       <th>b0241</th>
#       <td>0.106477</td>
#       <td>0.073934</td>
#       <td>0.086256</td>
#       <td>0.022749</td>
#       <td>0.086256</td>
#       <td>0.018957</td>
#     </tr>
#     <tr>
#       <th>b0929</th>
#       <td>2.592525</td>
#       <td>2.416360</td>
#       <td>1.610600</td>
#       <td>1.535846</td>
#       <td>1.485907</td>
#       <td>1.137561</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>b4031</th>
#       <td>0.119774</td>
#       <td>0.089040</td>
#       <td>0.070282</td>
#       <td>0.049492</td>
#       <td>0.074802</td>
#       <td>0.038870</td>
#     </tr>
#     <tr>
#       <th>b1857</th>
#       <td>0.439914</td>
#       <td>0.409871</td>
#       <td>0.296853</td>
#       <td>0.323677</td>
#       <td>0.300072</td>
#       <td>0.232117</td>
#     </tr>
#     <tr>
#       <th>b1859</th>
#       <td>0.177495</td>
#       <td>0.189384</td>
#       <td>0.109979</td>
#       <td>0.126115</td>
#       <td>0.140127</td>
#       <td>0.108280</td>
#     </tr>
#     <tr>
#       <th>b1858</th>
#       <td>0.393377</td>
#       <td>0.390728</td>
#       <td>0.275938</td>
#       <td>0.258720</td>
#       <td>0.245916</td>
#       <td>0.229581</td>
#     </tr>
#   </tbody>
# </table>
# <p>1424 rows × 6 columns</p>
# </div>

# %% [markdown]
# ### Visualize the expression data

# %%
data.boxplot()
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2a100415-3300-4c3c-80dc-a77f6625bbd2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2a100415-3300-4c3c-80dc-a77f6625bbd2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2a100415-3300-4c3c-80dc-a77f6625bbd2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3614601e-0993-4d9e-96f1-89ab30b84008":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["label","fill_alpha","line_alpha","color","height","y","line_color","x","width"],"data":{"chart_index":[{"condition":"t0"}],"color":["#3288bd"],"condition":["t0"],"fill_alpha":[0.8],"height":[0.18625508521246292],"label":[{"condition":"t0"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["t0"],"y":[0.13926906134390404]}},"id":"bb65e40d-2d20-44a8-a180-c04df6dc99d0","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"fcc41e4e-815b-423c-b7d0-1acc9b2f6efd","type":"Circle"},{"attributes":{"plot":{"id":"1e19a178-a5dd-47cf-89aa-21a13026eaa1","subtype":"Chart","type":"Plot"}},"id":"596e20eb-8aa3-4b91-ac34-f22275be718f","type":"PanTool"},{"attributes":{"callback":null,"column_names":["label","fill_alpha","line_alpha","color","height","y","line_color","x","width"],"data":{"chart_index":[{"condition":"t5"}],"color":["#d53e4f"],"condition":["t5"],"fill_alpha":[0.8],"height":[0.6945741541065431],"label":[{"condition":"t5"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["t5"],"y":[0.6745142958973321]}},"id":"e01f90ef-e68b-48cb-8aa1-376744578c03","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t10"},{"condition":"t1 ...

# %%
data.histogram(bins=50, filter="value < 2", conditions=["t0", "t10"])
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="db45d2d6-044d-4790-8ad0-1e40ef51a7c5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("db45d2d6-044d-4790-8ad0-1e40ef51a7c5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'db45d2d6-044d-4790-8ad0-1e40ef51a7c5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {
type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1d4f4bee-4d85-4b2e-9bf3-8c9300044741","type":"PanTool"},{"id":"80bfba39-283a-4d6d-b400-00fa13ae1a5a","type":"BoxZoomTool"},{"id":"40080a82-4395-4fc4-b62b-61fc808f61f2","type":"WheelZoomTool"},{"id":"982abdea-2844-4ace-977e-390b27c07a2b","type":"ResizeTool"},{"id":"86f311b0-cbc5-4710-80dd-19d126794d11","type":"ResetTool"},{"id":"072f75a8-51fb-40dc-9aa6-032dcf600851","type":"SaveTool"},{"id":"3f7794ce-5469-4541-8ea0-566c7e2a4f19","type":"HoverTool"}]},"id":"7b872c98-77c6-43b7-b1ca-567d9823a05b","type":"Toolbar"},{"attributes":{"plot":{"id":"1df9dcb7-731d-42d0-be36-3f28b642fcef","subtype":"Chart","type":"Plot"}},"id":"86f311b0-cbc5-4710-80dd-19d126794d11","type":"ResetTool"},{"attributes":{"plot":null,"text":"Expression values t0 vs. t10"},"id":"6d9cc3c2-ff0f-41c9-8852-179142bf857e","type":"Title"},{"attributes":{"plot":{"id":"1df9dcb7-731d-42d0-be36-3f28b642fcef","subtype":"Chart","type":"Plot"}},"id":"072f75a8-51fb-40dc-9aa6-032dcf600851","type":"SaveTool"},{"attributes":{"plot":{"id":"1df9dcb7-731d-42d0-be36-3f28b642fcef","subtype":"Chart","type":"Plot"}},"id":"982abdea-2844-4ace-977e-390b27c07a2b","type":"ResizeTool"},{"attributes":{"plot":{"id":"1df9dcb7-731d-42d0-be36-3f28b642fcef","subtype":"Chart","type":"Plot"}},"id":"40080a82-4395-4fc4-b62b-61fc808f61f2","type":"WheelZoomTool"},{"attributes":{"axis_label":"Expression t10","formatter":{"id":"3c125cbd-7385-4827-a674-0a9a2bf940a9","type":"BasicTickFormatter"},"plot":{"id":"1df9dcb7-731d-42d0-be36-3f28b642fcef","subtype":"Chart","type":"Plot"},"ticker":{"id":"6698b3f4-1122-4a27-8b51-0fab8e5d6fe9","type":"BasicTicker"}},"id":"2913e749-84b5-49ba-8056-b039d8fb345f","type":"LinearAxis"},{"attributes":{"overlay":{"id":"afedd534-0c7a-41ea-a8fe-d295231488ab","type":"BoxAnnotation"},"plot":{"id":"1df9dcb7-731d-42d0-be36-3f28b642fcef","subtype":"Chart","type":"Plot"}},"id":"80bfba39-283a-4d6d-b400-00fa13ae1a5a","type":"BoxZoomTool"},{"attributes":{"axis_label":"Expression t0","formatter":{"id":"3c565b69-3b71-4d7c-beaf-d3ad05316f5f","type":"BasicTickFormatter"},"plot":{"id":"1df9dcb7-731d-42d0-be36-3f28b642fcef","subtype":"Chart","type":"Plot"},"ticker":{"id":"70a507ed-e167-4f72-800c-b9b8ea961449","type":"BasicTicker"}},"id":"05cae4bc-9a86-4b64-9f11-2db1c1a4f3a8","type":"LinearAxis"},{"attributes":{},"id":"3c565b69-3b71-4d7c-beaf-d3ad05316f5f","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"1df9dcb7-731d-42d0-be36-3f28b642fcef","subtype":"Chart","type":"Plot"},"tooltips":[["Id","@index"]]},"id":"3f7794ce-5469-4541-8ea0-566c7e2a4f19","type":"HoverTool"},{"attributes":{},"id":"6698b3f4-1122-4a27-8b51-0fab8e5d6fe9","type":"BasicTicker"},{"attributes":{"below":[{"id":"05cae4bc-9a86-4b64-9f11-2db1c1a4f3a8","type":"LinearAxis"}],"height":494,"left":[{"id":"2913e749-84b5-49ba-8056-b039d8fb345f","type":"LinearAxis"}],"renderers":[{"id":"afedd534-0c7a-41ea-a8fe-d295231488ab","type":"BoxAnnotation"},{"id":"ba42294f-945c-4b00-adc0-7d82b2407d04","type":"GlyphRenderer"},{"id":"22b470dc-2ba3-4e81-bc71-e95b12a3e6e4","type":"Legend"},{"id":"05cae4bc-9a86-4b64-9f11-2db1c1a4f3a8","type":"LinearAxis"},{"id":"2913e749-84b5-49ba-8056-b039d8fb345f","type":"LinearAxis"},{"id":"6810f09d-998c-4cdb-8199-f4d50209c691","type":"Grid"},{"id":"745154d7-a7a3-4441-8e2b-d1d2885dc7a1","type":"Grid"}],"title":{"id":"6d9cc3c2-ff0 ...

# %%
data.scatter("t0", "t05", color="green", transform=lambda x: log2(x+1))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1e745fbe-6d57-4432-bd14-2d7330c065bd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1e745fbe-6d57-4432-bd14-2d7330c065bd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1e745fbe-6d57-4432-bd14-2d7330c065bd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"581231c5-6fda-4e83-9daf-cd91df64de5c":{"roots":{"references":[{"attributes":{"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"}},"id":"ab76396d-f12d-4ef9-ad59-e096466f14e1","type":"SaveTool"},{"attributes":{},"id":"5b3377e3-e568-415e-bb1f-84837a8658f9","type":"BasicTicker"},{"attributes":{"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"},"ticker":{"id":"70003fbd-1c2b-47bc-bd43-dab7e1f718cd","type":"BasicTicker"}},"id":"f6255484-8041-4cb3-9040-77a6a4f4432b","type":"Grid"},{"attributes":{"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"}},"id":"fd45bfb1-1db9-46dc-bf92-782a40d0b10d","type":"ResetTool"},{"attributes":{},"id":"dfa2c463-9cec-473b-8427-effd89e6930d","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"},"ticker":{"id":"5b3377e3-e568-415e-bb1f-84837a8658f9","type":"BasicTicker"}},"id":"a23f40e6-afa6-4fa6-af22-688c414d55e3","type":"Grid"},{"attributes":{},"id":"44bef57b-4eea-462c-902e-06c9a077c114","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Expression t05","formatter":{"id":"0fa51e91-d369-4fd1-ac01-a95e65e3602d","type":"BasicTickFormatter"},"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"},"ticker":{"id":"5b3377e3-e568-415e-bb1f-84837a8658f9","type":"BasicTicker"}},"id":"295a19b3-0f39-4b57-a02e-50da64a30e54","type":"LinearAxis"},{"attributes":{"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"}},"id":"802d8f7f-5b8b-4ad4-b774-6da2bb956ea9","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8648abeb-3536-41c8-ae55-154b1d1bd1ce","type":"PanTool"},{"id":"5cda9850-0cbc-4e40-b17e-6fdc0bc8b081","type":"BoxZoomTool"},{"id":"802d8f7f-5b8b-4ad4-b774-6da2bb956ea9","type":"WheelZoomTool"},{"id":"74cdbc93-10f6-4071-9ff9-36abb559dc8c","type":"ResizeTool"},{"id":"fd45bfb1-1db9-46dc-bf92-782a40d0b10d","type":"ResetTool"},{"id":"ab76396d-f12d-4ef9-ad59-e096466f14e1","type":"SaveTool"},{"id":"0f539c9c-acd9-40ba-bedc-6f9142b1e42d","type":"HoverTool"}]},"id":"d6c5af6f-19a5-40df-adc0-bf0e3a27c9d2","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f4ae9c6b-8cd9-43de-a146-cb3736a54d2a","type":"BoxAnnotation"},{"attributes":{},"id":"0fa51e91-d369-4fd1-ac01-a95e65e3602d","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"},"tooltips":[["Id","@index"]]},"id":"0f539c9c-acd9-40ba-bedc-6f9142b1e42d","type":"HoverTool"},{"attributes":{"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"}},"id":"74cdbc93-10f6-4071-9ff9-36abb559dc8c","type":"ResizeTool"},{"attributes":{},"id":"70003fbd-1c2b-47bc-bd43-dab7e1f718cd","type":"BasicTicker"},{"attributes":{"data_source":{"id":"76953cd7-1043-42f2-b9aa-44c225b14c39","type":"ColumnDataSource"},"glyph":{"id":"98befde3-c44c-4ba7-8e3c-3cc6baeb0fa2","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"66af951c-1d1d-40a5-8310-cd10787812e9","type":"GlyphRenderer"},{"attributes":{"axis_label":"Expression t0","formatter":{"id":"44bef57b-4eea-462c-902e-06c9a077c114","type":"BasicTickFormatter"},"plot":{"id":"97461f08-df1b-4c9d-9df9-16609eb62439","subtype":"Chart","type":"Plot"},"ticker":{"id":"70003fbd-1c2b-47bc-bd43-dab7e1f718cd","type":"BasicTicker"}},"id":"54191a62-5430-4897-9a66-02b112709702","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[null,n ...

# %% [markdown]
# ### Run GIMME
#
# GIMME is an algorithm to integrate expression data in the genome scale model. It computes the flux distribution that minimizes the inconsistence between the data and a feasible flux distribution.

# %%
from driven.flux_analysis.transcriptomics import gimme

# %% [markdown]
# Anaerobic conditions (t0)

# %%
anaerobic_result = gimme(ecoli, data, cutoff=0.2, condition="t0", fraction_of_optimum=0.1)

# %%
anaerobic_result
# Out:
# <strong>objective value: 0.007172896716398856</strong>

# %%
anaerobic_result.distance
# Out:
# 554.1198323565461

# %%
anaerobic_result.data_frame.query("inconsistency_scores > 0")
# Out:
#         gimme_fluxes  fba_fluxes  expression  inconsistency_scores
# ADCL    6.572067e-05    0.000657    0.109600          5.941127e-06
# ADCS    6.572067e-05    0.000657    0.091770          7.112930e-06
# AMAOTr  1.964744e-07    0.000002    0.136799          1.241746e-08
# AOXSr2  1.964744e-07    0.000002    0.171866          5.527615e-09
# ...              ...         ...         ...                   ...
# ORPT   -3.249637e-02   -0.324964    0.042642          5.113573e-03
# PNTK    5.658462e-05    0.000566    0.195088          2.779595e-07
# PTPATi  5.658462e-05    0.000566    0.121781          4.425964e-06
# TDSK    1.911303e-03    0.019113    0.122042          1.490015e-04
#
# [27 rows x 4 columns]

# %% [markdown]
# Then for aerobic conditions (t10)

# %%
aerobic_result = gimme(ecoli, data, cutoff=0.2, condition="t10", fraction_of_optimum=0.8)

# %%
anaerobic_result
# Out:
# <strong>objective value: 0.007172896716398856</strong>

# %%
aerobic_result.distance
# Out:
# 167.50727633290444

# %%
aerobic_result.data_frame.query("inconsistency_scores > 0")
# Out:
#          gimme_fluxes  fba_fluxes  expression  inconsistency_scores
# ADCL         0.000526    0.000657    0.154100              0.000024
# ADCS         0.000526    0.000657    0.146240              0.000028
# APRAUR       0.000351    0.000438    0.051677              0.000052
# BMOGDS1      0.000096    0.000120    0.140982              0.000006
# ...               ...         ...         ...                   ...
# GCALDD       0.000526    0.000657    0.182071              0.000009
# MPTG         0.010919    0.013649    0.127687              0.000790
# ORPT        -0.259971   -0.324964    0.062923              0.035636
# TDSK         0.015290    0.019113    0.169709              0.000463
#
# [12 rows x 4 columns]

# %% [markdown]
# ### Visualize the results

# %%
anaerobic_result.display_on_map("iJO1366.Central metabolism")
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.4/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="snnccyucho"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({
#              paths: {
#                d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                escher: '//npmcdn.com/escher-vis@1.4.4/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up npmcdn links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            })
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.4/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"snnccyucho"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"ignore_bootstrap": true, "reaction_scale": [{"color": "#2C7FB8", "size": 24, "type": "min"}, {"color": "#2C7FB8", "value": -4.265407685642636, "size": 21, "type": "value"}, {"color": "#7FCDBB", "value": -2.132703842821318, "size": 16, "type": "value"}, {"color": "#EDF8B1", "value": 0, "size": 8, "type": "value"}, {"color": "#7FCDBB", "value": 2.132703842821318, "size": 16, "type": "value"}, {"color": "#2C7FB8", "value": 4.265407685642636, "size": 21, "type": "value"}, {"color": "#2C7FB8", "size": 24, "type": "max"}], "scroll_behavior": "none", "gene_data": null, "enable_keys": false, "reaction_data": {"ICDHyr": 0.105624, "NH4tex": 2.749477, "CYSTL": 0.01512, "EX_quin_e": 1.662883, "DHDPRy": 0.036441, "UMPK": 0.037137, "ACt2rpp": -0.057231, "QUINDH": -1.662883, "PRAGSr": 0.044034, "SHKK": 0.03744, "DHFR": 0.002636, "EX_ni2_e": -3.2e-05, "3HAD140": 0.012538, "GMPS2": 0.023942, "DMATT": 2.7e-05, "GART": 0.010969, "IGPS": 0.005584, "ASP1DC": 5.7e-05, "GLNS": 0.263104, "EX_mg2_e": -0.000852, "PRAIi": 0.005584, "3HAD80": 0.034961, "FE2tpp": 0.000811, "PFK_3": 1.700345, "ORPT": -0.032496, "UPP3MT": 2.2e-05, "DHNPA2r": 6.6e-05, "PFK": 2.317632, "IPPS": 1.732694, "CHORM": 0.031768, "RPI": -1.7921, "MOHMT": 5.7e-05, "PGK": -8.027378, "3OAS160": 0
e-05, "PSSA160": 0.006269, "EX_fe3_e": -0.000767, "GRTT": 2.7e-05, "LEUt2rpp": -1.688435, "HCO3E": 0.342646, "GARFT": 0.033064, "QUIN2tex": -1.662883, "Zn2tex": 3.3e-05, "EAR140x": 0.012538, "G1SAT": 0.000351, "PAPPT3": 0.00273, "GND": 3.496355, "MTHFC": 0.086405, "PPNDH": 0.0182, "EX_h2o_e": 14.966888, "ANS": 0.005584, "PGL": 3.496355, "EAR161x": 0.014778, "PPC": 0.290785, "GLUPRT": 0.044034, "3OAR140": 0.020183, "Kt2pp": 0.019175, "HBZOPT": 2.2e-05, "EAR60x": 0.034961, "DHPTDC ...

# %%
aerobic_result.display_on_map("iJO1366.Central metabolism")
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.4/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="fqmzdhzhtb"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({
#              paths: {
#                d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                escher: '//npmcdn.com/escher-vis@1.4.4/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up npmcdn links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            })
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.4/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"fqmzdhzhtb"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"ignore_bootstrap": true, "reaction_scale": [{"color": "#2C7FB8", "size": 24, "type": "min"}, {"color": "#2C7FB8", "value": -10.079977658494633, "size": 21, "type": "value"}, {"color": "#7FCDBB", "value": -5.039988829247316, "size": 16, "type": "value"}, {"color": "#EDF8B1", "value": 0, "size": 8, "type": "value"}, {"color": "#7FCDBB", "value": 5.039988829247316, "size": 16, "type": "value"}, {"color": "#2C7FB8", "value": 10.079977658494633, "size": 21, "type": "value"}, {"color": "#2C7FB8", "size": 24, "type": "max"}], "scroll_behavior": "none", "gene_data": null, "enable_keys": false, "reaction_data": {"ICDHyr": 3.831694, "NH4tex": 8.48834, "CYSTL": 0.120958, "DHDPRy": 0.291528, "PPM": -0.000529, "UMPK": 0.2971, "TKT2": 1.019506, "G6PDH2r": 4.422878, "PRAGSr": 0.352269, "SHKK": 0.29952, "DHFR": 0.02109, "EX_ni2_e": -0.000254, "GMPS2": 0.191536, "DMATT": 0.000218, "GART": 0.001928, "3OAS140": 0.161464, "ASP1DC": 0.000453, "GLNS": 2.104835, "EX_mg2_e": -0.006818, "PAPSR2": 0.194802, "PRAIi": 0.044673, "3HAD80": 0.279685, "FE2tpp": 0.006486, "PFK_3": 1.319202, "NADH16pp": 26.861421, "ORPT": -0.259971, "UPP3MT": 0.000175, "DHNPA2r": 0.000526, "SUCDi": 3.2472, "CHORM": 0.254147, "RPI": -2.052888, "MOHMT": 0.000453, "PGK": -12.965293, "3OAS160": 0.100303, "PGCD": 1.39498, "PRAMPC": 0.074454, "3OAS60": 0.279685, "GLYCL": 0.042914, "MPTSS": 0.000384, "EX_meoh_e": 2e-06, "GLYCLTt2rpp": -0.000526,
# %% [markdown]
# ## Add physiological data
#
# Anaerobic conditions (t0)
#
# Oxigen uptake rate is 0

# %%
ecoli.reactions.EX_o2_e.lower_bound = 0
anaerobic_result = gimme(ecoli, data, cutoff=0.2, condition="t0", fraction_of_optimum=0.8)

# %%
anaerobic_result
# Out:
# <strong>objective value: 0.014106803175460755</strong>

# %%
anaerobic_result.distance
# Out:
# 77.86068207308439

# %%
anaerobic_result.data_frame.query("abs(gimme_fluxes) >= 1e-6 and abs(fba_fluxes) < 1e-6")
# Out:
#              gimme_fluxes  fba_fluxes  expression  inconsistency_scores
# EX_leu__L_e      0.035292         0.0         NaN                   0.0
# 3HAD100          0.068756         0.0    3.266667                   0.0
# 3HAD120          0.039694         0.0    3.266667                   0.0
# 3HAD121          0.029063         0.0    3.266667                   0.0
# ...                   ...         ...         ...                   ...
# SUCOAS           0.101404         0.0    0.288454                   0.0
# T2DECAI          0.029063         0.0    2.500644                   0.0
# THRt2pp          0.001006         0.0    0.380645                   0.0
# TRPS1            0.010982         0.0    1.168321                   0.0
#
# [50 rows x 4 columns]

# %%
anaerobic_result.display_on_map("iJO1366.Central metabolism")
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.4/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="lgdqneiwuo"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({
#              paths: {
#                d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                escher: '//npmcdn.com/escher-vis@1.4.4/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up npmcdn links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            })
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.4/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"lgdqneiwuo"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"ignore_bootstrap": true, "reaction_scale": [{"color": "#2C7FB8", "size": 24, "type": "min"}, {"color": "#2C7FB8", "value": -6.38625210608117, "size": 21, "type": "value"}, {"color": "#7FCDBB", "value": -3.193126053040585, "size": 16, "type": "value"}, {"color": "#EDF8B1", "value": 0, "size": 8, "type": "value"}, {"color": "#7FCDBB", "value": 3.193126053040585, "size": 16, "type": "value"}, {"color": "#2C7FB8", "value": 6.38625210608117, "size": 21, "type": "value"}, {"color": "#2C7FB8", "size": 24, "type": "max"}], "scroll_behavior": "none", "gene_data": null, "enable_keys": false, "reaction_data": {"ICDHyr": 0.207728, "NH4tex": 2.122024, "CYSTL": 0.029736, "DHDPRy": 0.071668, "PPM": -0.000216, "UMPK": 0.073038, "TKT2": -0.111831, "ACt2rpp": -7.164345, "PRAGSr": 0.0866, "SHKK": 0.073633, "DHFR": 0.005185, "EX_ni2_e": -6.2e-05, "GMPS2
, "DASYN160": 0.012329, "TYRTA": -0.026685, "PDX5POi": 4.3e-05, "ACGK": 0.057147, "DASYN161": 0.014531, "I2FE2SS": 5.5e-05, "UHGADA": 0.007518, "DALAt2pp": 0.002684, "DAPDC": 0.066299, "SERAT": 0.047889, "G3PD2": -0.02686, "VALTA": -0.194074, "GTPCII2": 8.6e-05, "CS": 0.207728, "CPMPS": 4.7e-05, "DHORTS": -0.06391, "EX_k_e": -0.037712, "I2FE2SS2": 5e-05, "EX_fe3_e": -0.001509, "GRTT": 5.4e-05, "LEUt2rpp": -0.035292, "HCO3E": 0.673875, "MECDPDH5": 0.000462, "TKT1": -0.038156, "Zn2tex": 6.6e-05, "G1SAT": 0.000689, "PAPPT3": 0.005369, "PSERT": 0.332386, "MTHFC": 0.169931, "CAt6pp": -0.001006, "EX_h2o_e": -1.929982, "PYK": 7.09283, "ANS": 0.010982, "UAMAGS": 0.005369, "EAR161x": 0.029063, "PPC": 0.63592, "GLUPRT": 0.0866, "3OAR140": 0.039694, "Kt2pp": 0.037712, "HBZOPT": 4.3e-05, "EAR60x": 0.068756, "DHPTDCs2": 8.7e-05, "ADC ...

# %%
aerobic_result.data_frame.query("abs(gimme_fluxes) >= 1e-6 and abs(fba_fluxes) < 1e-6")
# Out:
#              gimme_fluxes  fba_fluxes  expression  inconsistency_scores
# EX_glyclt_e      0.000526         0.0         NaN                   0.0
# 3HAD100          0.279685         0.0    4.516088                   0.0
# 3HAD120          0.161464         0.0    4.516088                   0.0
# 3HAD121          0.118221         0.0    4.516088                   0.0
# ...                   ...         ...         ...                   ...
# KAS15            0.279685         0.0    1.422875                   0.0
# PRPPS            0.733157         0.0    3.535375                   0.0
# T2DECAI          0.118221         0.0    4.516088                   0.0
# TRPS1            0.044673         0.0    0.625724                   0.0
#
# [52 rows x 4 columns]

# %% [markdown]
# ## Compare flux distributions

# %%
diff = anaerobic_result - aerobic_result

# %%
diff.normalize(ecoli.reactions.BIOMASS_Ec_iJO1366_core_53p95M)

# %%
diff.euclidean_distance
# Out:
# 346.8515724396443

# %%
diff.manhattan_distance
# Out:
# 2058.2382994254635

# %%
diff.data_frame.query("abs(fold_change) >= 1")
# Out:
#            fluxes_A  fluxes_B  manhattan_distance  euclidean_distance  \
# TKT2      -0.578833  1.297251            1.876084            3.519691
# LEUt2rpp  -0.182668  0.000000            0.182668            0.033368
# THRt4pp    0.005205  0.000000            0.005205            0.000027
# TALA      -0.197491  0.000000            0.197491            0.039003
# ...             ...       ...                 ...                 ...
# CS         1.075192  4.875565            3.800373           14.442838
# PFL       78.416207  0.000000           78.416207         6149.101561
# SUCCt3pp   0.331464  0.000000            0.331464            0.109868
# FUM        0.711380  4.843217            4.131837           17.072080
#
#           activity_profile  fold_change
# TKT2                   0.0     3.241149
# LEUt2rpp               1.0     1.000000
# THRt4pp                1.0     1.000000
# TALA                   1.0     1.000000
# ...                    ...          ...
# CS                     0.0    -3.534600
# PFL                    1.0     1.000000
# SUCCt3pp               1.0     1.000000
# FUM                    0.0    -5.808200
#
# [44 rows x 6 columns]
