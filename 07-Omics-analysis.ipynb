# %%
from bokeh.plotting import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="40c188ad-cfd4-411e-a26a-500821c5e2b2">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Read the counts with pandas.
#
# **pandas** is an efficient library to handle tabular data.
# It provides a DataFrame class similar to *R* data.frame.
#
# The data is the counts normalized by gene length. This is an example of how to use the code. In real life examples it should be RPKM or expression values.

# %%
from pandas import DataFrame

# %%
samples = DataFrame.from_csv('data/GSE71562_normalized.csv')

# %%
samples.head()
# Out:
#          E14R012a01  E14R012a02  E14R012a03  E14R012a04  E14R012a05  \
# bnumber
# b0001        6.9231      9.6923     10.2769      9.6769      7.1846
# b0002        9.1275      7.1543      8.3359     14.7218      5.2482
# b0003        5.7833      5.3562      5.8541     11.1620      3.1406
# b0004        8.1897      6.1742      6.7963     11.0918      3.6998
# b0005        0.3176      0.2196      0.2973      0.4189      0.1926
#
#          E14R012a06  E14R012b01  E14R012b02  E14R012b03  E14R012b04  \
# bnumber
# b0001        5.8154      4.9846      9.1538     11.0308     16.1077
# b0002        2.3672      4.7506      4.2543     11.6145     12.4184
# b0003        2.3144      3.9474      3.5172      6.6878      8.7543
# b0004        2.9673      4.2582      3.7278      8.0342      7.9518
# b0005        0.2061      0.2128      0.1858      0.3581      0.3007
#
#          E14R012b05  E14R012b06  E14R012c01  E14R012c02  E14R012c03  \
# bnumber
# b0001       19.8615     22.4462      5.9692     13.8308     19.4154
# b0002       16.3331     12.3477      2.4699      7.5016     14.9764
# b0003       10.7403      9.6470      2.0365      6.7296     11.6749
# b0004       10.8748     10.1734      2.2877      8.0288     13.2465
# b0005        0.4358      0.4696      0.0980      0.4020      0.6250
#
#          E14R012c04  E14R012c05  E14R012c06
# bnumber
# b0001       16.0308      7.0462     13.2615
# b0002       12.1706      6.3306      7.2616
# b0003        8.2543      3.7693      5.4485
# b0004        9.3593      4.3033      6.2185
# b0005        0.5068      0.1791      0.2230

# %% [markdown]
# ### Load *E. coli* model

# %%
from cameo import models
# Out:
# /usr/local/Cellar/pyenv/1.0.8/versions/3.6.0/envs/py36c/lib/python3.6/site-packages/bokeh/util/deprecation.py:34 BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.

# %%
ecoli = models.bigg.iJO1366

# %% [markdown]
# ### Keep metabolic genes only

# %%
model_filter = [g.id for g in ecoli.genes if g.id in samples.index]
samples = samples.loc[model_filter]

# %% [markdown]
# ### Aggregate the replicas using median

# %%
timepoints = {
    "t0":  ["E14R012a01", "E14R012b01", "E14R012c01"],
    "t05": ["E14R012a02", "E14R012b02", "E14R012c02"],
    "t1":  ["E14R012a03", "E14R012b03", "E14R012c03"],
    "t2":  ["E14R012a04", "E14R012b04", "E14R012c04"],
    "t5":  ["E14R012a05", "E14R012b05", "E14R012c05"],
    "t10": ["E14R012a06", "E14R012b06", "E14R012c06"],
}

# %%
for t, columns in timepoints.items():
    samples[t] = samples[columns].mean(axis=1)

# %%
samples = samples[[k for k in timepoints]]

# %% [markdown]
# ### Build the expression profile from the data

# %%
from driven.data_sets import ExpressionProfile
# Out:
# /usr/local/Cellar/pyenv/1.0.8/versions/3.6.0/envs/py36c/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning:
#
# pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#
# /usr/local/Cellar/pyenv/1.0.8/versions/3.6.0/envs/py36c/lib/python3.6/site-packages/ggplot/stats/smoothers.py:4: FutureWarning:
#
# The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#
# /usr/local/Cellar/pyenv/1.0.8/versions/3.6.0/envs/py36c/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning:
#
# The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.

# %%
data = ExpressionProfile.from_data_frame(samples)
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>t0</th>
#       <th>t05</th>
#       <th>t1</th>
#       <th>t2</th>
#       <th>t5</th>
#       <th>t10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>b2215</th>
#       <td>37.3560</td>
#       <td>46.4515</td>
#       <td>73.8450</td>
#       <td>76.8296</td>
#       <td>39.7604</td>
#       <td>28.8833</td>
#     </tr>
#     <tr>
#       <th>b1377</th>
#       <td>0.0106</td>
#       <td>0.0112</td>
#       <td>0.0088</td>
#       <td>0.0138</td>
#       <td>0.0132</td>
#       <td>0.0206</td>
#     </tr>
#     <tr>
#       <th>b0241</th>
#       <td>0.0190</td>
#       <td>0.0227</td>
#       <td>0.0739</td>
#       <td>0.1065</td>
#       <td>0.0863</td>
#       <td>0.0863</td>
#     </tr>
#     <tr>
#       <th>b0929</th>
#       <td>1.1376</td>
#       <td>1.5358</td>
#       <td>2.4164</td>
#       <td>2.5925</td>
#       <td>1.6106</td>
#       <td>1.4859</td>
#     </tr>
#     <tr>
#       <th>b4035</th>
#       <td>0.0239</td>
#       <td>0.0173</td>
#       <td>0.0326</td>
#       <td>0.0164</td>
#       <td>0.0114</td>
#       <td>0.0179</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>b3568</th>
#       <td>0.0319</td>
#       <td>0.0262</td>
#       <td>0.0356</td>
#       <td>0.0325</td>
#       <td>0.0305</td>
#       <td>0.0409</td>
#     </tr>
#     <tr>
#       <th>b4031</th>
#       <td>0.0389</td>
#       <td>0.0495</td>
#       <td>0.0890</td>
#       <td>0.1198</td>
#       <td>0.0703</td>
#       <td>0.0748</td>
#     </tr>
#     <tr>
#       <th>b1858</th>
#       <td>0.2296</td>
#       <td>0.2587</td>
#       <td>0.3907</td>
#       <td>0.3934</td>
#       <td>0.2759</td>
#       <td>0.2459</td>
#     </tr>
#     <tr>
#       <th>b1859</th>
#       <td>0.1083</td>
#       <td>0.1261</td>
#       <td>0.1894</td>
#       <td>0.1775</td>
#       <td>0.1100</td>
#       <td>0.1401</td>
#     </tr>
#     <tr>
#       <th>b1857</th>
#       <td>0.2321</td>
#       <td>0.3237</td>
#       <td>0.4099</td>
#       <td>0.4399</td>
#       <td>0.2969</td>
#       <td>0.3001</td>
#     </tr>
#   </tbody>
# </table>
# <p>1424 rows × 6 columns</p>
# </div>

# %% [markdown]
# ### Visualize the expression data

# %%
data.boxplot()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dd863354-0201-4fa0-9b9b-4cbfd8dc1463"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dd863354-0201-4fa0-9b9b-4cbfd8dc1463");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dd863354-0201-4fa0-9b9b-4cbfd8dc1463");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dd863354-0201-4fa0-9b9b-4cbfd8dc1463' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7fcfa29a-c6d3-41a0-b21f-eedd08383e50":{"roots":{"references":[{"attributes":{},"id":"e65216d8-1993-4e55-812d-fe41e42a7801","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9694f68f-ff41-4f25-b780-dd545e979f60","type":"PanTool"},{"id":"89b6277f-3468-433a-b44e-4f8204f967a8","type":"WheelZoomTool"},{"id":"d3329579-4efa-4402-8347-8121765ee7e0","type":"BoxZoomTool"},{"id":"6f9c8d30-5289-47ef-b4c1-c41ab7fed4f2","type":"SaveTool"},{"id":"fee10f7c-f42a-46f7-929d-93ed5b04b5c6","type":"ResetTool"},{"id":"c3f83a35-be17-437b-ae2c-c06822a6366b","type":"HelpTool"}]},"id":"62e1f787-04a3-482a-9ea8-3a46ade0aca2","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"},{"condition":"t05"}],"condition":["t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05","t05 ...
# Chart(id='8c9e6727-955d-49b2-9f57-41c4a48ce670', ...)

# %%
data.histogram(bins=50, filter="value < 2", conditions=["t0", "t10"])
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="507a0df8-65a5-41ce-a8fe-a3b6e4618bb2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("507a0df8-65a5-41ce-a8fe-a3b6e4618bb2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("507a0df8-65a5-41ce-a8fe-a3b6e4618bb2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '507a0df8-65a5-41ce-a8fe-a3b6e4618bb2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e5b1d946-cef0-4602-a560-a09ec6989288":{"roots":{"references":[{"attributes":{"data_source":{"id":"1fefcc81-54ea-4197-9cb7-31c981d94b9c","type":"ColumnDataSource"},"glyph":{"id":"301076ef-71fe-41be-a968-b93847d9c6a3","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a5bbc87f-bf35-4421-8fac-7bb052126e1e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(1.941345, 1.980964]"],"color":["#ffffbf"],"fill_alpha":[0.6],"height":[4.0],"label":["(1.941345, 1.980964]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03961927582534619],"x":["1.9611545000000001"],"y":[2.0]}},"id":"1fefcc81-54ea-4197-9cb7-31c981d94b9c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b0b4d27-ee65-44cb-864f-ad46836168f7","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c2bbb125-941e-4a76-bb0e-90a71c292a35","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"49619337-22a3-49bf-b4bf-3977195238fc","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7aa2b6e0-ead8-4eb7-88d3-f0219e2dc3cf","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"28dc7d0d-10f4-438a-ab21-763dc4d0bca7","type":"Rect"},{"attributes":{"data_source":{"id":"66eac34d-1fd8-405c-983a-823dbcdefd98","type":"ColumnDataSource"},"glyph":{"id":"06ad3962-58cc-4821-995b-0dcd8640c5c2","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"491d1d9b-16c0-46d3-bd99-a8e230830047","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9476a1f4-e404-48a3-9f92-b45ef2f0f8d9","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e02d1209-6310-470c-b64f-56b351ff748b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb6f77d3-6a66-461d-a350-50afcea6c731","type":"Rect"},{"attributes":{"data_source":{"id":"0b4b3997-7405-4096-a5eb-d2d43c0ec121","type":"ColumnDataSource"},"glyph":{"id":"ee940811-90af-44ee-9241-3b5982d60ae3","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e222432f-6e31-414f-bc7e-5dc030a411ee","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"05b4c78 ...
# Chart(id='e26ac2fe-f06d-4234-8702-43217b1c24ee', ...)

# %%
from numpy import log2

# %%
data.scatter("t0", "t10", color="orange", transform=lambda x: log2(x+1))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c0316788-5768-4a72-9f57-6a6336b00cf3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c0316788-5768-4a72-9f57-6a6336b00cf3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0316788-5768-4a72-9f57-6a6336b00cf3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0316788-5768-4a72-9f57-6a6336b00cf3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"be8fc469-8345-4438-b1dc-91f7b5eb731a":{"roots":{"references":[{"attributes":{},"id":"e1e8c840-e29b-4658-b4a8-48ecc419c82b","type":"LinearScale"},{"attributes":{"location":"top_left","plot":{"id":"fad64661-8306-4d83-9706-82541239e573","subtype":"Chart","type":"Plot"}},"id":"0607a0a0-ccb6-403a-b7f4-1d1552ca893d","type":"Legend"},{"attributes":{},"id":"03682bde-ae90-487c-80fb-c9f3a6989217","type":"LinearScale"},{"attributes":{"axis_label":"Expression t0","formatter":{"id":"4a0c0721-f9c5-4f90-aa2d-486ceed79aa1","type":"BasicTickFormatter"},"plot":{"id":"fad64661-8306-4d83-9706-82541239e573","subtype":"Chart","type":"Plot"},"ticker":{"id":"b7b4bd86-2153-47f0-ac3d-8dc6c2bee436","type":"BasicTicker"}},"id":"fafbcbb3-a994-43c1-a7fa-e9da2fa1765f","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Expression values t0 vs. t10"},"id":"0c29f385-078c-4b40-afd5-523eb6b5b34c","type":"Title"},{"attributes":{},"id":"b7b4bd86-2153-47f0-ac3d-8dc6c2bee436","type":"BasicTicker"},{"attributes":{"overlay":{"id":"c57aa50f-2177-467a-b634-46d5fb569a8d","type":"BoxAnnotation"},"plot":{"id":"fad64661-8306-4d83-9706-82541239e573","subtype":"Chart","type":"Plot"}},"id":"6dc8fa5d-7eb5-4110-8656-e9ad494cf33a","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"fad64661-8306-4d83-9706-82541239e573","subtype":"Chart","type":"Plot"}},"id":"301b2885-6de3-49ee-a932-77113dc0cfd0","type":"PanTool"},{"attributes":{},"id":"c7d9db1d-93ff-40ad-bfad-adec00405163","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c57aa50f-2177-467a-b634-46d5fb569a8d","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"fafbcbb3-a994-43c1-a7fa-e9da2fa1765f","type":"LinearAxis"}],"css_classes":null,"height":494,"left":[{"id":"7c2b2c82-9663-4f6f-a037-0b80ccbc9b9c","type":"LinearAxis"}],"renderers":[{"id":"c57aa50f-2177-467a-b634-46d5fb569a8d","type":"BoxAnnotation"},{"id":"0d77224b-f691-46a9-a919-8abbe3f08974","type":"GlyphRenderer"},{"id":"0607a0a0-ccb6-403a-b7f4-1d1552ca893d","type":"Legend"},{"id":"fafbcbb3-a994-43c1-a7fa-e9da2fa1765f","type":"LinearAxis"},{"id":"7c2b2c82-9663-4f6f-a037-0b80ccbc9b9c","type":"LinearAxis"},{"id":"3501e9c5-ffd8-41ac-b1ba-cce17886f130","type":"Grid"},{"id":"4c1cff56-ed14-4133-98e5-cadac9a160f5","type":"Grid"}],"title":{"id":"0c29f385-078c-4b40-afd5-523eb6b5b34c","type":"Title"},"tool_events":{"id":"a1aaa5f1-ce09-437c-9e4a-a1e7b7b484c5","type":"ToolEvents"},"toolbar":{"id":"cbe24b7a-098f-4e7d-be52-b1345fe48509","type":"Toolbar"},"width":800,"x_range":{"id":"227276c0-37a9-4711-9cb8-6517b173d4d2","type":"Range1d"},"x_scale":{"id":"03682bde-ae90-487c-80fb-c9f3a6989217","type":"LinearScale"},"y_range":{"id":"0c3799e3-204d-4761-858e-932f4c4faee0","type":"Range1d"},"y_scale":{"id":"e1e8c840-e29b-4658-b4a8-48ecc419c82b","type":"LinearScale"}},"id":"fad64661-8306-4d83-9706-82541239e573","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"4a0c0721-f9c5-4f90-aa2d-486ceed79aa1","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"fad64661-8306-4d83-9706-82541239e573","subtype":"Chart","type":"Plot"},"ticker":{"id":"a74d4aa8-f99a-48b7-a795-19d389d19ab7","type":"BasicTicker"}},"id":"4c1cff56-ed14-4133-98e5-cadac9a160f5","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"orange"},"line_color":{"value":"orange"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"cee5ba3d-810f-418c-8d89-91693f2a447e","type":"Circle"},{"attributes":{},"id":"a74d4aa8-f99a-48b7-a795-19d389d19ab7","type":"BasicTicker"},{"attributes":{"plot":{"id":"fad64661-8306-4d83-9706-82541239e573","subtype":"Chart","type":"Plot"}},"id":"28e14477-a56a-4e12-b911-68f41b2abb4f","type":" ...
# Chart(id='fad64661-8306-4d83-9706-82541239e573', ...)

# %% [markdown]
# ## Excercise 1
#
# Scatter plots can be use to get a feeling about the changes in the data.
#
# 1. Find out which timepoints are more similar and more far away.
# 2. Between t0 and t5, which genes changed more.
#
# You can change the axis data using the column ids in the data.
#
# <code>data.scatter(<column 1>, <column 2>, color="green", transform=lambda x: log2(x+1))<code/>

# %% [markdown]
# ### Run GIMME
#
# GIMME is an algorithm to integrate expression data in the genome scale model. It computes the flux distribution that minimizes the inconsistence between the data and a feasible flux distribution.

# %%
from driven.flux_analysis.transcriptomics import gimme

# %% [markdown]
# Anaerobic conditions (t0)

# %%
anaerobic_result = gimme(ecoli, data, cutoff=0.2, condition="t0", fraction_of_optimum=0.1)

# %%
anaerobic_result
# Out:
# <strong>objective value: 0.00717289671639887</strong>

# %%
anaerobic_result.distance
# Out:
# 618.7956947887177

# %%
anaerobic_result.data_frame.query("inconsistency_scores > 0")
# Out:
#         gimme_fluxes  fba_fluxes  expression  inconsistency_scores
# ADCL      6.5721e-05  6.5721e-04      0.1096            5.9411e-06
# ADCS      6.5721e-05  6.5721e-04      0.0918            7.1129e-06
# AMAOTr    1.9647e-07  1.9647e-06      0.1368            1.2417e-08
# AOXSr2    1.9647e-07  1.9647e-06      0.1719            5.5276e-09
# APRAUR    4.3814e-05  4.3814e-04      0.0623            6.0352e-06
# ...              ...         ...         ...                   ...
# OPHBDC    2.1907e-05  2.1907e-04      0.1394            1.3270e-06
# ORPT     -3.2496e-02 -3.2496e-01      0.0426            5.1136e-03
# PNTK      5.6585e-05  5.6585e-04      0.1951            2.7796e-07
# PTPATi    5.6585e-05  5.6585e-04      0.1218            4.4260e-06
# TDSK      1.9113e-03  1.9113e-02      0.1220            1.4900e-04
#
# [27 rows x 4 columns]

# %% [markdown]
# Then for aerobic conditions (t10)

# %%
aerobic_result = gimme(ecoli, data, cutoff=0.2, condition="t10", fraction_of_optimum=0.8)

# %%
anaerobic_result
# Out:
# <strong>objective value: 0.00717289671639887</strong>

# %%
aerobic_result.distance
# Out:
# 150.59379985802906

# %%
aerobic_result.data_frame.query("inconsistency_scores > 0")
# Out:
#          gimme_fluxes  fba_fluxes  expression  inconsistency_scores
# ADCL       5.2577e-04      0.0007      0.1541            2.4133e-05
# ADCS       5.2577e-04      0.0007      0.1462            2.8265e-05
# APRAUR     3.5051e-04      0.0004      0.0517            5.1989e-05
# BMOGDS1    9.5879e-05      0.0001      0.1410            5.6586e-06
# BMOGDS2    9.5879e-05      0.0001      0.1410            5.6586e-06
# ...               ...         ...         ...                   ...
# DHPPDA2    3.5051e-04      0.0004      0.0517            5.1989e-05
# GCALDD     5.2577e-04      0.0007      0.1821            9.4265e-06
# MPTG       1.0919e-02      0.0136      0.1277            7.8960e-04
# ORPT      -2.5997e-01     -0.3250      0.0629            3.5636e-02
# TDSK       1.5290e-02      0.0191      0.1697            4.6316e-04
#
# [12 rows x 4 columns]

# %% [markdown]
# ### Visualize the results

# %%
anaerobic_result.display_on_map("iJO1366.Central metabolism")
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id
151, "DASYN161": 0.05911, "DB4PS": 0.000701, "DBTS": 2e-06, "DDPA": 0.29952, "DHAD1": 0.687086, "DHAD2": 0.228326, "DHDPRy": 0.291528, "DHDPS": 0.291528, "DHFR": 0.02109, "DHFS": 0.000526, "DHNPA2r": 0.000526, "DHORD5": 0.259971, "DHORTS": -0.259971, "DHPPDA2": 0.000351, "DHPS2": 0.000526, "DHPTDCs2": 0.000352, "DHQS": 0.29952, "DHQTi": 0.29952, "DMATT": 0.000218, "DMPPS": 0.000218, "DNMPPA": 0.000526, "DNTPPA": 0.000526, "DPCOAK": 0.000453, "DPR": 0.000453, "DTMPK": 0.020564, "DUTPDP": 0.020564, "DXPRIi": 0.001878, "DXPS": 0.002228, "E4PD": 0.000175, "EAR100x": 0.161464, "EAR120x": 0.161464, "EAR121x": 0.118221, "EAR140x": 0.100303, "EAR141x": 0.118221, "EAR160x": 0.100303, "EAR161x": 0.118221, "EAR40x": 0.279685, "EAR60x": 0.279685, "EAR80x": 0.279685, "EGMEACPR": 2e-06, "ENO": 12.271628, "EPMEACPR": 2e-06, "FADRx": 0.000633, "FBA": 4.65825, "FBA3": 1.572804, "FCLT": 0.000175, "FE2tex": 0.0126 ...

# %% [markdown]
# ## Compare flux distributions

# %%
diff = anaerobic_result - aerobic_result

# %%
diff.normalize(ecoli.reactions.BIOMASS_Ec_iJO1366_core_53p95M)

# %%
diff.euclidean_distance
# Out:
# 440.75038540607784

# %%
diff.manhattan_distance
# Out:
# 2600.5167213695272

# %%
diff.data_frame.query("abs(fold_change) >= 1")
# Out:
#            fluxes_A  fluxes_B  manhattan_distance  euclidean_distance  \
# EX_ac_e     57.7157    0.0000             57.7157          3.3311e+03
# EX_quin_e   18.7843    0.0000             18.7843          3.5285e+02
# ACONTa       1.0752    4.9403              3.8651          1.4939e+01
# ACONTb       1.0752    4.9403              3.8651          1.4939e+01
# ADPT         0.0011    0.0000              0.0011          1.2522e-06
# ...             ...       ...                 ...                 ...
# SUCOAS       0.5249   -3.3402              3.8651          1.4939e+01
# THD2pp      75.4744    0.0000             75.4744          5.6964e+03
# TRDR         1.2909    0.0000              1.2909          1.6665e+00
# TRPS2        0.0568    0.0000              0.0568          3.2311e-03
# TRPS3        0.0568    0.0000              0.0568          3.2311e-03
#
#            activity_profile  fold_change
# EX_ac_e                 1.0       1.0000
# EX_quin_e               1.0       1.0000
# ACONTa                  0.0      -3.5948
# ACONTb                  0.0      -3.5948
# ADPT                    1.0       1.0000
# ...                     ...          ...
# SUCOAS                  0.0       7.3640
# THD2pp                  1.0       1.0000
# TRDR                    1.0       1.0000
# TRPS2                   1.0       1.0000
# TRPS3                   1.0       1.0000
#
# [30 rows x 6 columns]

# %% [markdown]
# ## Exercise 2
#
# Assess the effect of the different RNA-seq data points.
#
# 1. Change the condition used to constraint the model and simulate it.
# 2. Visualize the data.
# 3. Explore the fluxes that change comparing with the aerobic conditions.

# %% [markdown]
# ## Add physiological data
#
# Anaerobic conditions (t0)
#
# Oxigen uptake rate is 0

# %%
ecoli.reactions.EX_o2_e.lower_bound = 0
anaerobic_result = gimme(ecoli, data, cutoff=0.2, condition="t0", fraction_of_optimum=0.8)

# %%
anaerobic_result
# Out:
# <strong>objective value: 0.014106803175460918</strong>

# %%
anaerobic_result.distance
# Out:
# 29.569655625425845

# %%
anaerobic_result.data_frame.query("abs(gimme_fluxes) >= 1e-6 and abs(fba_fluxes) < 1e-6")
# Out:
#          gimme_fluxes  fba_fluxes  expression  inconsistency_scores
# 3HAD100        0.0688         0.0      3.2667                   0.0
# 3HAD120        0.0397         0.0      3.2667                   0.0
# 3HAD121        0.0291         0.0      3.2667                   0.0
# 3HAD140        0.0247         0.0      3.2667                   0.0
# 3HAD141        0.0291         0.0      3.2667                   0.0
# ...               ...         ...         ...                   ...
# SUCOAS         0.1014         0.0      0.2885                   0.0
# T2DECAI        0.0291         0.0      2.5006                   0.0
# THRt2pp        0.0010         0.0      0.3806                   0.0
# THRt4pp        0.0010         0.0      3.4566                   0.0
# TRPS2          0.0110         0.0      1.1683                   0.0
#
# [47 rows x 4 columns]

# %%
anaerobic_result.display_on_map("iJO1366.Central metabolism")
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="nqiynbtxdv"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"nqiynbtxdv"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"DM_4crsol_c": 4.3e-05, "DM_5drib_c": 0.00013, "DM_mththf_c": 8.7e-05, "BIOMASS_Ec_iJO1366_core_53p95M": 0.193201, "EX_ac_e": 8.566105, "EX_ca2_e": -0.001006, "EX_cl_e": -0.001006, "EX_co2_e": -0.070583, "EX_cobalt2_e": -5e-06, "EX_cu2_e": -0.000137, "EX_etoh_e": 8.462135, "EX_fe2_e": -0.001594, "EX_fe3_e": -0.001509, "EX_for_e": 17.826656, "EX_glc__D_e": -10.0, "EX_glyclt_e": 0.000129, "EX_h_e": 28.297656, "EX_h2o_e": -3.367034, "EX_k_e": -0.037712, "EX_mg2_e": -0.001676, "EX_mn2_e": -0.000134, "EX_mobd_e": -2.5e-05, "EX_nh4_e": -2.086733, "EX_ni2_e": -6.2e-05, "EX_pi_e": -0.186368, "EX_so4_e": -0.048727, "EX_succ_e": 0.064039, "EX_zn2_e": -6.6e-05, "3HAD100": 0.068756, "3HAD120": 0.039694, "3HAD121": 0.029063, "3HAD140": 0.024658, "3HAD141": 0.029063, "3HAD160": 0.024658, "3HAD161": 0.029063, "3HAD40": 0.068756, "3HAD60": 0.068756, "3HAD80": 0.068756, "3OAR100": 0.068756, "3OAR120": 0.039694, "3OAR121": 0.029063, "3OAR140": 0.039694, "3OAR141": 0.029063, "3OAR160": 0.024658, "3OAR161": 0.029063, "3OAR40": 0.068756, "3OAR60": 0.068756, "3OAR80": 0.068756, "3OAS100": 0.068756, "3OAS120": 0.039694, "3OAS121": 0.029063, "3OAS140": 0.039694, "3OAS141": 0.029063, "3OAS160": 0.024658, "3OAS161": 0.029063, "3OAS60": 0.068756, "3OAS80": 0.068756, "5DOAN": 0.00013, "A5PISO": 0.007518, "ACALD": -8.462135, "ACCOAC": 0.466261, "ACGK": 0.057147, "ACGS": 0.057147, "ACHBS": 0.056131, "ACKr": -8.453551, "ACLS": 0.16891, "ACOATA": 0.068756, "ACODA": 0.057147, "ACONTa": 0.207728, "ACONTb": 0.207728, "ACOTA": -0.057147, "ACt2rpp": -8.566105, "ACtex": -8.566105, "ADCL": 0.000129, "ADCS": 0.000129, "ADK1": 0.438476, "ADNK1": 0.000216, "ADSK": 0.047889, "ADSL1r": 0.057774, "ADSL2r": 0.086557, "ADSS": 0.057774, "AGPAT160": 0.012329, "AGPAT161": 0.014531, "AGPR": -0.057147, "AHCYSNS": 8.7e-05, "AICART": 0.104861, "AIRC2": 0.086557, "AIRC3": -0.086557, "ALAALAr": 0.005369, "ALAR": 0.008053, "ALATA_L": -0.194074, "ALCD2x": -8.462135, "AMPMS2": 4.3e-05, "ANPRT": 0.010982, "ANS": 0.010982, "APRAUR": 8.6e-05, "ARGSL": 0.057147, "ARGSS": 0.057147, "ASAD": -0.206547, "ASNS1": 0.046572, "ASP1DC": 0.000111, "ASPCT": 0.06391, "ASPK": 0.206547, "ASPO6": 0.00044, "ASPTA": -0.565631, "ATPM": 6.606258, "ATPPRT": 0.018303, "ATPS4rpp": -6.430011, "BMOCOS": 2.4e-05, "BMOGDS1": 2.4e-05, "BMOGDS2": 2.4e-05, "BPNT": 0.047889, "CA2tex": 0.001006, "CAt6pp": -0.001006, "CBPS": 0.121057, "CDPMEK": 0.000462, "CHORM": 0.062478, "CHORS": 0.073633, "CHRPL": 4.3e-05, "CLt3_2pp": 0.000503, "CLtex": 0.001006, "CO2tex": 0.070583, "CO2tpp": 0.070583, "COBALT2tex": 5e-06, "COBALT2tpp": 5e-06, "CPMPS": 4.7e-05, "CPPPGO2": 4.3e-05, "CS": 0.207728, "CTPS2": 0.031014, "CU2tex": 0.000137, "CU2tpp": 0.000137, "CYSS": 0.047889, "CYSTL": 0.029736, "CYTK1": 0.034951, "DALAt2pp": 0.002684, "DAPDC": 0.066299, "DAPE": 0.071668, "DASYN160": 0.012329, "DASYN161": 0.014531, "DB4PS": 0.000172, "DDPA": 0.073633, "DHAD1": 0.16891, "DHAD2": 0.056131, "DHDPRy": 0.071668, "DHDPS": 0.071668, "DHFR": 0.005185, "DHFS": 0.000129, "DHNPA2r": 0.000129, "DHORD5": 0.06391, "DHORTS": -0.06391, "DHPPDA2": 8.6e-05, "DHPS2": 0.000129, "DHPTDCs2": 8.7e-05, "DHQS": 0.073633, "DHQTi": 0.073633, "DMATT": 5.4e-05, "DMPPS": 5.4e-05, "DNMPPA": 0.000129, "DNTPPA": 0.000129, "DPCOAK": 0.000111, "DPR": 0.000111, "DTMPK": 0.005055, "DUTPDP": 0.005055, "DXPRIi": 0.000462, "DXPS": 0.000548, "E4PD": 4.3e-05, "EAR100x": 0.039694, "EAR120x": 0.039694, "EAR121x": 0.029063, "EAR140x": 0.024658, "EAR141x": 0.029063, "EAR160x": 0.024658, "EAR161x": 0.029063, "EAR40x": 0.068756, "EAR60x": 0.068756, "EAR80x": 0.068756, "ENO": 19.202433, "ETOHtex": -8.462135, "ETOHtrpp": -8.462135, "FADRx": 0.000156, "FBA": 9.831758, "FCLT": 4.3e-05, "FE2tex": 0.001594, "FE2tpp": 0.001594, "FE3abcpp": 0.001509, "FE3tex": 0.001509, "FM ...

# %%
aerobic_result.data_frame.query("abs(gimme_fluxes) >= 1e-6 and abs(fba_fluxes) < 1e-6")
# Out:
#              gimme_fluxes  fba_fluxes  expression  inconsistency_scores
# EX_glyclt_e        0.0005         0.0         NaN                   0.0
# EX_hom__L_e        0.6505        -0.0         NaN                   0.0
# 3HAD100            0.2797         0.0      4.5161                   0.0
# 3HAD120            0.1615         0.0      4.5161                   0.0
# 3HAD121            0.1182         0.0      4.5161                   0.0
# ...                   ...         ...         ...                   ...
# PRPPS              0.7332         0.0      3.5354                   0.0
# PUNP1             -0.0009         0.0      1.9226                   0.0
# T2DECAI            0.1182         0.0      4.5161                   0.0
# THRt2pp            0.0041         0.0      0.4570                   0.0
# TRPS1              0.0447         0.0      0.6257                   0.0
#
# [57 rows x 4 columns]
